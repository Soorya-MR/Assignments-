# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_excel(r'C:\Users\ACER\Downloads\iris.xls')

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Display the columns in the dataset

# %%
print(df.SL)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
print(df.SW)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
print(df.PL)
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PL, Length: 150, dtype: float64

# %%
print(df.PW)
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
print(df.Classification)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Classification, Length: 150, dtype: object

# %% [markdown]
# ### mean of each column

# %%
mean_SL = df['SL'].mean()
print("Mean of the 'SL' column:", mean_SL)
# Out:
# Mean of the 'SL' column: 5.843333333333334

# %%
mean_SW = df['SW'].mean()
print("Mean of the 'SW' column:", mean_SW)
# Out:
# Mean of the 'SW' column: 3.0540000000000003

# %%
mean_PL = df['PL'].mean()
print("Mean of the 'PL' column:", mean_PL)
# Out:
# Mean of the 'PL' column: 3.758666666666666

# %%
mean_PW = df['PW'].mean()
print("Mean of the 'PW' column:", mean_PW)
# Out:
# Mean of the 'PW' column: 1.1986666666666668

# %% [markdown]
# ### null value

# %%
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)
# Out:
# Null values in each column:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### visualizations

# %%
df[['SL', 'SW', 'PL', 'PW']].hist(bins=15, figsize=(10, 8), grid=False)
# Out:
# array([[<Axes: title={'center': 'SL'}>, <Axes: title={'center': 'SW'}>],
#        [<Axes: title={'center': 'PL'}>, <Axes: title={'center': 'PW'}>]],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
subset_df = df[['SL', 'SW', 'PL', 'PW','Classification']]

# %%
sns.pairplot(subset_df, hue='Classification', diag_kind='hist', height=2.5)

# %%
plt.suptitle('Pairplot of Sepal and Petal Dimensions (SL, SW, PL, PW)', y=1.02)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Classification', y='SL', data=df)
plt.title('Boxplot of SL by Classification')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Classification', y='SW', data=df)
plt.title('Boxplot of SL by Classification')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Classification', y='PL', data=df)
plt.title('Boxplot of SL by Classification')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Classification', y='PW', data=df)
plt.title('Boxplot of SL by Classification')
plt.show()
